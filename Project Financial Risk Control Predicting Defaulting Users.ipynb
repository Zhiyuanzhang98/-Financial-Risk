# %% [markdown]
# #  数据清洗和数据分析

# %%
import pandas as pd
import numpy as np

# %%
train_data=pd.read_csv("金融科技.csv")
test_data=pd.read_csv("金融科技testB.csv")

# %%
train_data
# Out:
#             id  loanAmnt  term  interestRate  installment grade subGrade  \
# 0            0   35000.0     5         19.52       917.97     E       E2
# 1            1   18000.0     5         18.49       461.90     D       D2
# 2            2   12000.0     5         16.99       298.17     D       D3
# 3            3   11000.0     3          7.26       340.96     A       A4
# 4            4    3000.0     3         12.99       101.07     C       C2
# ...        ...       ...   ...           ...          ...   ...      ...
# 799995  799995   25000.0     3         14.49       860.41     C       C4
# 799996  799996   17000.0     3          7.90       531.94     A       A4
# 799997  799997    6000.0     3         13.33       203.12     C       C3
# 799998  799998   19200.0     3          6.92       592.14     A       A4
# 799999  799999    9000.0     3         11.06       294.91     B       B3
#
#         employmentTitle employmentLength  homeOwnership  ...    n5    n6  \
# ...

# %%
test_data
# Out:
#              id  loanAmnt  term  interestRate  installment grade subGrade  \
# 0       1000000   12000.0     5         26.30       361.42     E       E5
# 1       1000001    7000.0     3          6.92       215.89     A       A4
# 2       1000002    8000.0     3          6.49       245.16     A       A2
# 3       1000003   35000.0     5         19.99       927.10     D       D5
# 4       1000004    1000.0     3         15.31        34.82     C       C5
# ...         ...       ...   ...           ...          ...   ...      ...
# 199995  1199995   25000.0     3         14.83       864.56     D       D3
# 199996  1199996   11200.0     3         11.99       371.95     B       B5
# 199997  1199997   14000.0     3          5.32       421.61     A       A1
# 199998  1199998    7725.0     3         17.99       279.24     D       D2
# 199999  1199999   25600.0     3          6.24       781.59     A       A2
#
#         employmentTitle employmentLength  homeOwnership  ...    n5    n6  \
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800000 entries, 0 to 799999
# Data columns (total 47 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  800000 non-null  int64
#  1   loanAmnt            800000 non-null  float64
#  2   term                800000 non-null  int64
#  3   interestRate        800000 non-null  float64
#  4   installment         800000 non-null  float64
#  5   grade               800000 non-null  object
#  6   subGrade            800000 non-null  object
#  7   employmentTitle     799999 non-null  float64
#  8   employmentLength    753201 non-null  object
#  9   homeOwnership       800000 non-null  int64
#  10  annualIncome        800000 non-null  float64
#  11  verificationStatus  800000 non-null  int64
#  12  issueDate           800000 non-null  object
#  13  isDefault           800000 non-null  int64
#  14  purpose             800000 non-null  int64
# ...

# %%
train_data.describe()
# Out:
#                   id       loanAmnt           term   interestRate  \
# count  800000.000000  800000.000000  800000.000000  800000.000000
# mean   399999.500000   14416.818875       3.482745      13.238391
# std    230940.252015    8716.086178       0.855832       4.765757
# min         0.000000     500.000000       3.000000       5.310000
# 25%    199999.750000    8000.000000       3.000000       9.750000
# 50%    399999.500000   12000.000000       3.000000      12.740000
# 75%    599999.250000   20000.000000       3.000000      15.990000
# max    799999.000000   40000.000000       5.000000      30.990000
#
#          installment  employmentTitle  homeOwnership  annualIncome  \
# count  800000.000000    799999.000000  800000.000000  8.000000e+05
# mean      437.947723     72005.351714       0.614213  7.613391e+04
# std       261.460393    106585.640204       0.675749  6.894751e+04
# min        15.690000         0.000000       0.000000  0.000000e+00
# ...

# %%
train_data.shape
# Out:
# (800000, 47)

# %%
train_data.columns
# Out:
# Index(['id', 'loanAmnt', 'term', 'interestRate', 'installment', 'grade',
#        'subGrade', 'employmentTitle', 'employmentLength', 'homeOwnership',
#        'annualIncome', 'verificationStatus', 'issueDate', 'isDefault',
#        'purpose', 'postCode', 'regionCode', 'dti', 'delinquency_2years',
#        'ficoRangeLow', 'ficoRangeHigh', 'openAcc', 'pubRec',
#        'pubRecBankruptcies', 'revolBal', 'revolUtil', 'totalAcc',
#        'initialListStatus', 'applicationType', 'earliesCreditLine', 'title',
#        'policyCode', 'n0', 'n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8',
#        'n9', 'n10', 'n11', 'n12', 'n13', 'n14'],
#       dtype='object')

# %%
train_data.isnull().any().sum()
# Out:
# 22

# %%
# nan可视化
missing = train_data.isnull().sum()/len(train_data)
missing = missing[missing > 0]
missing.sort_values(inplace=True)#排序
missing.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# 数值型数据变量处理
#训练集缺失值的处理     
train_data["dti"]=train_data["dti"].fillna(train_data["dti"].mean())
train_data["pubRecBankruptcies"]=train_data["pubRecBankruptcies"].fillna(train_data["pubRecBankruptcies"].mean())
train_data["revolUtil"]=train_data["revolUtil"].fillna(train_data["revolUtil"].mean())
for i in np.arange(32,47,1):#匿名特征的填充
    train_data.iloc[:,i]=train_data.iloc[:,1].fillna(train_data.iloc[:,1].mean())
#测试集缺失值的处理
test_data["dti"]=test_data["dti"].fillna(test_data["dti"].mean())
test_data["pubRecBankruptcies"]=test_data["pubRecBankruptcies"].fillna(test_data["pubRecBankruptcies"].mean())
test_data["revolUtil"]=test_data["revolUtil"].fillna(test_data["revolUtil"].mean())
for i in np.arange(31,46,1):
    test_data.iloc[:,i]=test_data.iloc[:,1].fillna(test_data.iloc[:,1].mean())

# %%
train_data
# Out:
#             id  loanAmnt  term  interestRate  installment grade subGrade  \
# 0            0   35000.0     5         19.52       917.97     E       E2
# 1            1   18000.0     5         18.49       461.90     D       D2
# 2            2   12000.0     5         16.99       298.17     D       D3
# 3            3   11000.0     3          7.26       340.96     A       A4
# 4            4    3000.0     3         12.99       101.07     C       C2
# ...        ...       ...   ...           ...          ...   ...      ...
# 799995  799995   25000.0     3         14.49       860.41     C       C4
# 799996  799996   17000.0     3          7.90       531.94     A       A4
# 799997  799997    6000.0     3         13.33       203.12     C       C3
# 799998  799998   19200.0     3          6.92       592.14     A       A4
# 799999  799999    9000.0     3         11.06       294.91     B       B3
#
#         employmentTitle  employmentLength  homeOwnership  ...       n5  \
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 46 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  200000 non-null  int64
#  1   loanAmnt            200000 non-null  float64
#  2   term                200000 non-null  int64
#  3   interestRate        200000 non-null  float64
#  4   installment         200000 non-null  float64
#  5   grade               200000 non-null  object
#  6   subGrade            200000 non-null  object
#  7   employmentTitle     200000 non-null  float64
#  8   employmentLength    188492 non-null  object
#  9   homeOwnership       200000 non-null  int64
#  10  annualIncome        200000 non-null  float64
#  11  verificationStatus  200000 non-null  int64
#  12  issueDate           200000 non-null  object
#  13  purpose             200000 non-null  int64
#  14  postCode            200000 non-null  float64
# ...

# %%
#缺失值的处理      文本型数据变量的处理    采用特征文本数据数值化
from sklearn.preprocessing import LabelEncoder as LE
train_data["employmentLength"]=LE().fit_transform(train_data["employmentLength"])
test_data["employmentLength"]=LE().fit_transform(test_data["employmentLength"])

# %%
#删除缺失值较少的特征的缺失所在行，并对列进行重洗排序
train_data.dropna(inplace=True)
train_data.index=range(train_data.shape[0])
test_data.dropna(inplace=True)
test_data.index=range(test_data.shape[0])

# %%
train_data
# Out:
#             id  loanAmnt  term  interestRate  installment grade subGrade  \
# 0            0   35000.0     5         19.52       917.97     E       E2
# 1            1   18000.0     5         18.49       461.90     D       D2
# 2            2   12000.0     5         16.99       298.17     D       D3
# 3            3   11000.0     3          7.26       340.96     A       A4
# 4            4    3000.0     3         12.99       101.07     C       C2
# ...        ...       ...   ...           ...          ...   ...      ...
# 799992  799995   25000.0     3         14.49       860.41     C       C4
# 799993  799996   17000.0     3          7.90       531.94     A       A4
# 799994  799997    6000.0     3         13.33       203.12     C       C3
# 799995  799998   19200.0     3          6.92       592.14     A       A4
# 799996  799999    9000.0     3         11.06       294.91     B       B3
#
#         employmentTitle  employmentLength  homeOwnership  ...       n5  \
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 46 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  200000 non-null  int64
#  1   loanAmnt            200000 non-null  float64
#  2   term                200000 non-null  int64
#  3   interestRate        200000 non-null  float64
#  4   installment         200000 non-null  float64
#  5   grade               200000 non-null  object
#  6   subGrade            200000 non-null  object
#  7   employmentTitle     200000 non-null  float64
#  8   employmentLength    200000 non-null  int32
#  9   homeOwnership       200000 non-null  int64
#  10  annualIncome        200000 non-null  float64
#  11  verificationStatus  200000 non-null  int64
#  12  issueDate           200000 non-null  object
#  13  purpose             200000 non-null  int64
#  14  postCode            200000 non-null  float64
# ...

# %%
train_data.isnull().any().sum()
# Out:
# 0

# %%
test_data.isnull().any().sum()
# Out:
# 0

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799997 entries, 0 to 799996
# Data columns (total 47 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  799997 non-null  int64
#  1   loanAmnt            799997 non-null  float64
#  2   term                799997 non-null  int64
#  3   interestRate        799997 non-null  float64
#  4   installment         799997 non-null  float64
#  5   grade               799997 non-null  object
#  6   subGrade            799997 non-null  object
#  7   employmentTitle     799997 non-null  float64
#  8   employmentLength    799997 non-null  int64
#  9   homeOwnership       799997 non-null  int64
#  10  annualIncome        799997 non-null  float64
#  11  verificationStatus  799997 non-null  int64
#  12  issueDate           799997 non-null  object
#  13  isDefault           799997 non-null  int64
#  14  purpose             799997 non-null  int64
# ...

# %%
#  6   subGrade            799997 non-null  object 
#  5   grade               799997 non-null  object 
#  12  issueDate           799997 non-null  object 
#  29  earliesCreditLine   799997 non-null  object
from sklearn.preprocessing import LabelEncoder as LE
train_data["subGrade"]=LE().fit_transform(train_data["subGrade"])
train_data["grade"]=LE().fit_transform(train_data["grade"])
train_data["issueDate"]=LE().fit_transform(train_data["issueDate"])
train_data["earliesCreditLine"]=LE().fit_transform(train_data["earliesCreditLine"])

test_data["subGrade"]=LE().fit_transform(test_data["subGrade"])
test_data["grade"]=LE().fit_transform(test_data["grade"])
test_data["issueDate"]=LE().fit_transform(test_data["issueDate"])
test_data["earliesCreditLine"]=LE().fit_transform(test_data["earliesCreditLine"])

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799997 entries, 0 to 799996
# Data columns (total 47 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  799997 non-null  int64
#  1   loanAmnt            799997 non-null  float64
#  2   term                799997 non-null  int64
#  3   interestRate        799997 non-null  float64
#  4   installment         799997 non-null  float64
#  5   grade               799997 non-null  int64
#  6   subGrade            799997 non-null  int64
#  7   employmentTitle     799997 non-null  float64
#  8   employmentLength    799997 non-null  int64
#  9   homeOwnership       799997 non-null  int64
#  10  annualIncome        799997 non-null  float64
#  11  verificationStatus  799997 non-null  int64
#  12  issueDate           799997 non-null  int64
#  13  isDefault           799997 non-null  int64
#  14  purpose             799997 non-null  int64
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 46 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  200000 non-null  int64
#  1   loanAmnt            200000 non-null  float64
#  2   term                200000 non-null  int64
#  3   interestRate        200000 non-null  float64
#  4   installment         200000 non-null  float64
#  5   grade               200000 non-null  int64
#  6   subGrade            200000 non-null  int64
#  7   employmentTitle     200000 non-null  float64
#  8   employmentLength    200000 non-null  int32
#  9   homeOwnership       200000 non-null  int64
#  10  annualIncome        200000 non-null  float64
#  11  verificationStatus  200000 non-null  int64
#  12  issueDate           200000 non-null  int64
#  13  purpose             200000 non-null  int64
#  14  postCode            200000 non-null  float64
# ...

# %%
#删除无用的数据
train_data.drop("grade",axis=1,inplace=True)
train_data.drop("employmentLength",axis=1,inplace=True)
train_data.drop("id",axis=1,inplace=True)

test_data.drop("grade",axis=1,inplace=True)
test_data.drop("employmentLength",axis=1,inplace=True)
test_data.drop("id",axis=1,inplace=True)

# %%
train_data
# Out:
#         loanAmnt  term  interestRate  installment  subGrade  employmentTitle  \
# 0        35000.0     5         19.52       917.97        21            320.0
# 1        18000.0     5         18.49       461.90        16         219843.0
# 2        12000.0     5         16.99       298.17        17          31698.0
# 3        11000.0     3          7.26       340.96         3          46854.0
# 4         3000.0     3         12.99       101.07        11             54.0
# ...          ...   ...           ...          ...       ...              ...
# 799992   25000.0     3         14.49       860.41        13           2659.0
# 799993   17000.0     3          7.90       531.94         3          29205.0
# 799994    6000.0     3         13.33       203.12        12           2582.0
# 799995   19200.0     3          6.92       592.14         3            151.0
# 799996    9000.0     3         11.06       294.91         7             13.0
#
# ...

# %%
test_data
# Out:
#         loanAmnt  term  interestRate  installment  subGrade  employmentTitle  \
# 0        12000.0     5         26.30       361.42        24         141873.0
# 1         7000.0     3          6.92       215.89         3             38.0
# 2         8000.0     3          6.49       245.16         1          97905.0
# 3        35000.0     5         19.99       927.10        19           1746.0
# 4         1000.0     3         15.31        34.82        14            196.0
# ...          ...   ...           ...          ...       ...              ...
# 199995   25000.0     3         14.83       864.56        17         234972.0
# 199996   11200.0     3         11.99       371.95         9         102496.0
# 199997   14000.0     3          5.32       421.61         0            288.0
# 199998    7725.0     3         17.99       279.24        16             54.0
# 199999   25600.0     3          6.24       781.59         1          74893.0
#
# ...

# %%
#删除重复值
train_data.drop_duplicates(inplace=True)

# %%
train_data.shape
# Out:
# (799997, 44)

# %% [markdown]
# #   特征工程

# %% [markdown]
# ### 无量纲化操作

# %%
Y=pd.DataFrame(train_data["isDefault"])
X=train_data.loc[:,train_data.columns!="isDefault"]

# %%
Y
# Out:
#         isDefault
# 0               1
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 799992          0
# 799993          0
# 799994          1
# 799995          0
# 799996          0
#
# [799997 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler as ss
ss=ss()
Train_data=pd.DataFrame(ss.fit_transform(X))
Test_data=pd.DataFrame(ss.fit_transform(test_data))

# %%
Train_data
# Out:
#               0         1         2         3         4         5         6   \
# 0       2.361518  1.772857  1.318073  1.835926  1.599082 -0.672559  2.050742
# 1       0.411102  1.772857  1.101948  0.091610  0.823469  1.387042 -0.908940
# 2      -0.277280  1.772857  0.787203 -0.534603  0.978592 -0.378166 -0.908940
# 3      -0.392011 -0.564061 -1.254445 -0.370945 -1.193124 -0.235970  0.570901
# 4      -1.309854 -0.564061 -0.052118 -1.288445  0.047856 -0.675055  0.570901
# ...          ...       ...       ...       ...       ...       ...       ...
# 799992  1.214214 -0.564061  0.262627  1.615778  0.358101 -0.650615  0.570901
# 799993  0.296371 -0.564061 -1.120153  0.359490 -1.193124 -0.401556 -0.908940
# 799994 -0.965662 -0.564061  0.019224 -0.898137  0.202979 -0.651337  0.570901
# 799995  0.548778 -0.564061 -1.325787  0.589735 -1.193124 -0.674145 -0.908940
# 799996 -0.621471 -0.564061 -0.457090 -0.547071 -0.572634 -0.675440 -0.908940
#
# ...

# %%
Test_data
# Out:
#               0         1         2         3         4         5         6   \
# 0      -0.276775  1.772735  2.736946 -0.292149  2.060671  0.651121  2.056912
# 1      -0.850872 -0.564100 -1.322113 -0.849783 -1.189241 -0.677270  0.573582
# 2      -0.736052 -0.564100 -1.412175 -0.737628 -1.498756  0.239328  2.056912
# 3       2.364068  1.772735  1.415344  1.875393  1.286882 -0.661273 -0.909749
# 4      -1.539787 -0.564100  0.435137 -1.543597  0.513094 -0.675790  0.573582
# ...          ...       ...       ...       ...       ...       ...       ...
# 199995  1.215875 -0.564100  0.334603  1.635755  0.977367  1.523062 -0.909749
# 199996 -0.368631 -0.564100 -0.260223 -0.251801 -0.260695  0.282326 -0.909749
# 199997 -0.047137 -0.564100 -1.657226 -0.061516 -1.653514 -0.674928 -0.909749
# 199998 -0.767628 -0.564100  0.996452 -0.607042  0.822609 -0.677120 -0.909749
# 199999  1.284767 -0.564100 -1.464536  1.317835 -1.498756  0.023803 -0.909749
#
# ...

# %%
from sklearn.feature_selection import SelectFromModel as SFM
from sklearn.linear_model import LogisticRegression as LR
from sklearn.model_selection import cross_val_score 
from sklearn.ensemble import RandomForestClassifier as RFC
import matplotlib.pyplot as plt

# %%
RFC_=RFC(n_estimators=10,random_state=420)
RFC_.fit(X,Y)
b=(RFC_.feature_importances_).max()
# Out:
# <ipython-input-74-2a7fc5df17f3>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC_.fit(X,Y)

# %%
b
# Out:
# 0.05795823365290189

# %%
a=[]
cc=np.linspace(0,0.05795823365290189,5)
RFC_=RFC(n_estimators=10,random_state=420)
for i in cc:
    X_SFM=SFM(RFC_,threshold=i).fit_transform(X,Y)
    score=cross_val_score(RFC_,X_SFM,Y,cv=2).mean()
    a.append(score)
plt.figure(figsize=(20,5))
plt.plot(cc,a)
plt.show()
# Out:
# E:\Phthon\lib\site-packages\sklearn\feature_selection\_from_model.py:234: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X, y, **fit_params)
# E:\Phthon\lib\site-packages\sklearn\model_selection\_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# E:\Phthon\lib\site-packages\sklearn\model_selection\_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
a=[]
cc=np.linspace(0.5,0.05795823365290189,5)
RFC_=RFC(n_estimators=10,random_state=420)
for i in cc:
    X_SFM=SFM(RFC_,threshold=i).fit_transform(X,Y)
    score=cross_val_score(RFC_,X_SFM,Y,cv=2).mean()
    a.append(score)
plt.figure(figsize=(20,5))
plt.plot(cc,a)
plt.show()
# Out:
# E:\Phthon\lib\site-packages\sklearn\feature_selection\_from_model.py:234: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X, y, **fit_params)
# E:\Phthon\lib\site-packages\sklearn\feature_selection\_base.py:90: UserWarning: No features were selected: either the data is too noisy or the selection test too strict.
#   warn("No features were selected: either the data is"
# E:\Phthon\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\Phthon\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\Phthon\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
# ...

# %%
X_SFM=SFM(RFC_,threshold=0.055).fit_transform(X,Y)
# Out:
# E:\Phthon\lib\site-packages\sklearn\feature_selection\_from_model.py:234: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X, y, **fit_params)

# %%
X_SFM=pd.DataFrame(X_SFM)
X_SFM.shape
# Out:
# (799997, 2)

# %%
RFC_=RFC(n_estimators=10,random_state=420)
RFC_.fit(X,Y)
# Out:
# <ipython-input-86-2a7fc5df17f3>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC_.fit(X,Y)

# %%
for i,j in zip(list(X.columns),list(RFC_.feature_importances_)):
    print(i,'的特征重要性是',j)
# Out:
# loanAmnt 的特征重要性是 0.010539284885119399
# term 的特征重要性是 0.012393283254723268
# interestRate 的特征重要性是 0.05549633234597809
# installment 的特征重要性是 0.03805114699112198
# subGrade 的特征重要性是 0.045717017309884804
# employmentTitle 的特征重要性是 0.05157232631863344
# homeOwnership 的特征重要性是 0.011287673298541048
# annualIncome 的特征重要性是 0.05000150651691035
# verificationStatus 的特征重要性是 0.01204401386480117
# issueDate 的特征重要性是 0.04622798174490551
# purpose 的特征重要性是 0.014125405245699692
# postCode 的特征重要性是 0.05028290799100615
# regionCode 的特征重要性是 0.03904120406067461
# dti 的特征重要性是 0.05795823365290189
# delinquency_2years 的特征重要性是 0.011007013665999784
# ficoRangeLow 的特征重要性是 0.027208863590307494
# ficoRangeHigh 的特征重要性是 0.028013383492488234
# openAcc 的特征重要性是 0.036850674364674846
# pubRec 的特征重要性是 0.007714486617658071
# pubRecBankruptcies 的特征重要性是 0.00541610481026592
# revolBal 的特征重要性是 0.05399381334047479
# revolUtil 的特征重要性是 0.05185673402803643
# totalAcc 的特征重要性是 0.043035701056176524
# ...

# %%
sorted(list(zip(list(X.columns),list(RFC_.feature_importances_))))
# Out:
# [('annualIncome', 0.05000150651691035),
#  ('applicationType', 0.0015258976651923938),
#  ('delinquency_2years', 0.011007013665999784),
#  ('dti', 0.05795823365290189),
#  ('earliesCreditLine', 0.050055243148607084),
#  ('employmentTitle', 0.05157232631863344),
#  ('ficoRangeHigh', 0.028013383492488234),
#  ('ficoRangeLow', 0.027208863590307494),
#  ('homeOwnership', 0.011287673298541048),
#  ('initialListStatus', 0.007150688568504413),
#  ('installment', 0.03805114699112198),
#  ('interestRate', 0.05549633234597809),
#  ('issueDate', 0.04622798174490551),
#  ('loanAmnt', 0.010539284885119399),
#  ('n0', 0.010839227634517369),
#  ('n1', 0.01118627302147327),
#  ('n10', 0.010732139066240712),
#  ('n11', 0.011047891659048055),
#  ('n12', 0.010599292494579417),
#  ('n13', 0.010466029071159356),
#  ('n14', 0.01093932509429834),
#  ('n2', 0.010733524960784209),
#  ('n3', 0.010448051621269234),
#  ('n4', 0.01052762946988587),
#  ('n5', 0.010211585651558953),
# ...

# %%
plt.figure(figsize=(20,5))
plt.plot(list(X.columns),list(RFC_.feature_importances_),color="orange",linestyle=":",linewidth=2)
plt.xticks(list(X.columns),list(X.columns),rotation=90)
plt.grid(alpha=0.7)
plt.legend(prop="simhei",loc=4)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ###  相关性数据分析

# %%
#相关性分析    返回该数据类型的相关系数矩阵（即每两个类型的直接相关性）
correlation=train_data.corr()
print(correlation['isDefault'].sort_values(ascending=False),'\n') #由大到小排序
# Out:
# isDefault             1.000000
# subGrade              0.267725
# interestRate          0.259204
# term                  0.175130
# verificationStatus    0.088556
# dti                   0.084949
# n14                   0.065211
# n2                    0.065211
# n13                   0.065211
# n0                    0.065211
# n1                    0.065211
# loanAmnt              0.065211
# n3                    0.065211
# n10                   0.065211
# n4                    0.065211
# n9                    0.065211
# n6                    0.065211
# n8                    0.065211
# n7                    0.065211
# n11                   0.065211
# n12                   0.065211
# n5                    0.065211
# revolUtil             0.059431
# homeOwnership         0.054597
# issueDate             0.052612
# installment           0.051525
# openAcc               0.026868
# pubRec                0.026558
# pubRecBankruptcies    0.026032
# delinquency_2years    0.020184
# ...

# %%
# method是计算相关系数的方法，默认是皮尔森相关系数；
# 如：A和B 存在一定的相关性，A对B存在一定程度的影响，A变化，B也会有一定的变化
# 如果A和B相等 或者 B可以由A经过计算得到---->完全相关
# 如果B是由 A和C计算得到 ---->并且 A可以计算出B的大部分 -----> A和B 强度相关
# 如果B是由 A和C计算得到 ---->并且 A可以计算出B的小部分 -----> A和B 弱度相关
# 如果 A和B 毫无关系 ----> 不相关
# 如果B和 A相关：
# A的增大导致B的减小 —> 负相关
# A的增大导致B的增大 —> 正相关
import scipy.stats as st
import seaborn as sns
plt.figure(figsize=(30,10))
plt.xticks(fontproperties="simhei",rotation=90)
plt.yticks(fontproperties="simhei",rotation=90)
sns.heatmap(correlation,square=True,vmax=0.8)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(30,10))
plt.plot(list(train_data.columns),list(correlation['isDefault']),color="black",linewidth=2)
plt.xticks(list(train_data.columns),list(train_data.columns),rotation=90)
plt.grid(alpha=0.7)
plt.legend(prop="simhei",loc=4)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
list(correlation['isDefault'])
# Out:
# [0.06521074211593536,
#  0.17513008236377767,
#  0.2592035723998552,
#  0.051524723625741224,
#  0.2677252326213811,
#  -0.03071230280791549,
#  0.05459691652598519,
#  -0.04278120657618058,
#  0.08855598083730504,
#  0.05261211472748132,
#  1.0,
#  -0.029208368348174817,
#  0.007139916987275866,
#  0.0028209791885759816,
#  0.08494903178656309,
#  0.020184083394160137,
#  -0.13099422494549817,
#  -0.13099311512280248,
#  0.026867776101218918,
#  0.026557574783086547,
#  0.026031637466507253,
#  -0.020927016421144435,
#  0.059431477715560434,
#  -0.012755482675552285,
#  -0.007381963066894346,
#  0.018196528603076124,
#  0.0014274736773491948,
#  -0.025173205430155377,
#  nan,
#  0.06521074211593536,
#  0.06521074211593536,
#  0.06521074211593536,
#  0.06521074211593536,
#  0.06521074211593536,
#  0.06521074211593536,
#  0.06521074211593536,
#  0.06521074211593536,
#  0.06521074211593536,
#  0.06521074211593536,
#  0.06521074211593536,
#  0.06521074211593536,
#  0.06521074211593536,
# ...

# %% [markdown]
# ### 数据特征分布可视化

# %%
#每个数字特征得分布可视化
f = pd.melt(train_data, value_vars=numerical_serial_fea)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")
# Out:
# E:\Phthon\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# E:\Phthon\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# E:\Phthon\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# E:\Phthon\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# E:\Phthon\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# E:\Phthon\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
# ...

# %%
f
# Out:
#           variable    value
# 0         loanAmnt  35000.0
# 1         loanAmnt  18000.0
# 2         loanAmnt  12000.0
# 3         loanAmnt  11000.0
# 4         loanAmnt   3000.0
# ...            ...      ...
# 35199863       n14  25000.0
# 35199864       n14  17000.0
# 35199865       n14   6000.0
# 35199866       n14  19200.0
# 35199867       n14   9000.0
#
# [35199868 rows x 2 columns]

# %%
train_data['pubRec'].value_counts()
# Out:
# 0.0     664762
# 1.0     113186
# 2.0      14520
# 3.0       4432
# 4.0       1535
# 5.0        757
# 6.0        367
# 7.0        165
# 8.0        105
# 9.0         51
# 10.0        37
# 11.0        23
# 12.0        14
# 15.0         7
# 13.0         6
# 18.0         4
# 16.0         4
# 19.0         2
# 21.0         2
# 20.0         2
# 22.0         2
# 24.0         2
# 49.0         2
# 14.0         2
# 63.0         1
# 47.0         1
# 46.0         1
# 86.0         1
# 54.0         1
# 28.0         1
# 40.0         1
# 17.0         1
# Name: pubRec, dtype: int64

# %%
train_data['policyCode'].value_counts()
# Out:
# 1.0    799997
# Name: policyCode, dtype: int64

# %%
train_data['subGrade'].value_counts()
# Out:
# 10    50763
# 8     49516
# 9     48965
# 7     48600
# 11    47068
# 12    44751
# 13    44271
# 6     44227
# 5     42382
# 14    40263
# 4     38045
# 3     30928
# 15    30538
# 16    26528
# 0     25909
# 17    23410
# 2     22655
# 1     22124
# 18    21138
# 19    17838
# 20    14064
# 21    12746
# 22    10925
# 23     9273
# 24     8653
# 25     5925
# 26     4340
# 27     3577
# 28     2859
# 29     2352
# 30     1759
# 31     1231
# 32      978
# 33      751
# 34      645
# Name: subGrade, dtype: int64

# %%
Data=pd.read_csv("金融科技.csv")
plt.figure(figsize=(30,10))
plt.plot(list(train_data.columns),list(correlation['isDefault']),color="black",linewidth=2)
plt.xticks(list(train_data.columns),list(train_data.columns),rotation=90)
plt.grid(alpha=0.7)
plt.legend(prop="simhei",loc=4)
plt.show()

# %%
# Data=pd.read_csv("金融科技.csv")
plt.figure(figsize=(20,10))
SubGrade=Data['subGrade'].value_counts()
plt.plot(SubGrade,color="black",linewidth=2)
plt.grid(alpha=0.7)
plt.legend(prop="simhei",loc=4)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
SubGrade
# Out:
# C1    50763
# B4    49516
# B5    48965
# B3    48600
# C2    47068
# C3    44751
# C4    44272
# B2    44227
# B1    42382
# C5    40264
# A5    38045
# A4    30928
# D1    30538
# D2    26528
# A1    25909
# D3    23410
# A3    22655
# A2    22124
# D4    21139
# D5    17838
# E1    14064
# E2    12746
# E3    10925
# E4     9273
# E5     8653
# F1     5925
# F2     4340
# F3     3577
# F4     2859
# F5     2352
# G1     1759
# G2     1231
# G3      978
# G4      751
# G5      645
# Name: subGrade, dtype: int64

# %%
plt.figure(figsize=(20,10))
interestRate=Data['interestRate'].value_counts()
interestRate.sort_values(inplace=True)
plt.bar(interestRate.index,interestRate,color="orange",width=0.3)
plt.grid(alpha=0.7)
plt.legend(prop="simhei",loc=4)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
interestRate=Data['interestRate'].value_counts().

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-207-8ee7a9075d55> in <module>
# ----> 1 interestRate.index.sort_values(inplace=True)
#
# TypeError: sort_values() got an unexpected keyword argument 'inplace'

# %%
interestRate
# Out:
# 22.64        1
# 17.54        1
# 14.25        1
# 15.01        1
# 14.75        1
#          ...
# 9.17     15523
# 5.32     17033
# 13.99    17420
# 11.99    19674
# 10.99    22549
# Name: interestRate, Length: 641, dtype: int64

# %%
#Ploting Transaction Amount Values Distribution
plt.figure(figsize=(16,12))
plt.suptitle('Transaction Values Distribution', fontsize=22)
plt.subplot(221)
sub_plot_1 = sns.distplot(train_data['interestRate'])
sub_plot_1.set_title("interestRate Distribuition", fontsize=18)
sub_plot_1.set_xlabel("")
sub_plot_1.set_ylabel("Probability", fontsize=15)

plt.subplot(222)
sub_plot_2 = sns.distplot(np.log(train_data['interestRate']))
sub_plot_2.set_title("interestRate(Log) Distribuition", fontsize=18)
sub_plot_2.set_xlabel("")
sub_plot_2.set_ylabel("Probability", fontsize=15)
# Out:
# Text(0, 0.5, 'Probability')

# %%
plt.figure(figsize=(16,12))
plt.suptitle('Transaction Values Distribution', fontsize=22)
plt.subplot(221)
sub_plot_1 = sns.distplot(train_data['subGrade'])
sub_plot_1.set_title("subGrade Distribuition", fontsize=18)
sub_plot_1.set_xlabel("")
sub_plot_1.set_ylabel("Probability", fontsize=15)
# Out:
# Text(0, 0.5, 'Probability')

# %%
# 贷款年限
plt.figure(figsize=(8, 8))
sns.barplot(train_data["term"].value_counts(dropna=False)[:20],
            train_data["term"].value_counts(dropna=False).keys()[:20])
plt.show()

# %%
train_data["term"]
# Out:
# 0         5
# 1         5
# 2         5
# 3         3
# 4         3
#          ..
# 799992    3
# 799993    3
# 799994    3
# 799995    3
# 799996    3
# Name: term, Length: 799997, dtype: int64

# %%
# 根绝y值不同可视化x某个特征的分布
train_loan_fr = Data.loc[Data['isDefault'] == 1]
train_loan_nofr = Data.loc[Data['isDefault'] == 0]

fig, ((ax1, ax2), (ax3, ax4),(ax5,ax6)) = plt.subplots(3,2,figsize=(20, 15))
train_loan_fr.groupby('grade')['grade'].count().plot(kind='barh', ax=ax1, title='Count of grade fraud')
train_loan_nofr.groupby('grade')['grade'].count().plot(kind='barh', ax=ax2, title='Count of grade non-fraud')
train_loan_fr.groupby('employmentLength')['employmentLength'].count().plot(kind='barh', ax=ax3, title='Count of employmentLength fraud')
train_loan_nofr.groupby('employmentLength')['employmentLength'].count().plot(kind='barh', ax=ax4, title='Count of employmentLength non-fraud')
train_loan_fr.groupby('term')['term'].count().plot(kind='barh', ax=ax5, title='Count of term  fraud')
train_loan_nofr.groupby('term')['term'].count().plot(kind='barh', ax=ax6, title='Count of term  non-fraud')
plt.show()

# %%
interestRate          0.259204
term                  0.175130
verificationStatus    0.088556
dti                   0.084949

# %%
Data['postCode'].value_counts()
# Out:
# 134.0    8956
# 19.0     8611
# 51.0     8161
# 31.0     7337
# 4.0      7176
#          ...
# 858.0       1
# 937.0       1
# 938.0       1
# 915.0       1
# 916.0       1
# Name: postCode, Length: 932, dtype: int64

# %%
#异常值处理
# 3σ原则

# 如果数据服从正态分布，在3σ原则下，异常值被定义为⼀组测定值中与平均值的偏差超过三倍标准差的值。

# 在正态分布下，距离平均值3σ之外的值出现的概率为 P(|x-µ|>3σ)<=0.003，属于极个别的⼩概率事件。

# 如果数据不服从正态分布，也可以⽤远离平均值的多少倍标准差来描述
def detect_outliers(data,threshold=3):
    mean_d = np.mean(data)
    std_d = np.std(data)
    outliers =[]
    for y in data:
        z_score=(y - mean_d)/std_d
        if np.abs(z_score)> threshold:
            outliers.append(y)
    return outliers

# %%
C=detect_outliers(data1['pubRec'])

# %%
data1['pubRec'].value_counts()
# Out:
# 0.0     663964
# 1.0     112992
# 2.0      14509
# 3.0       4429
# 4.0       1534
# 5.0        756
# 6.0        367
# 7.0        165
# 8.0        105
# 9.0         51
# 10.0        37
# 11.0        23
# 12.0        14
# 15.0         7
# 13.0         6
# 18.0         4
# 16.0         4
# 19.0         2
# 21.0         2
# 20.0         2
# 22.0         2
# 24.0         2
# 49.0         2
# 14.0         2
# 63.0         1
# 47.0         1
# 46.0         1
# 86.0         1
# 54.0         1
# 28.0         1
# 40.0         1
# 17.0         1
# Name: pubRec, dtype: int64

# %%
def find_outliers_by_3segama(data,fea):
    data_std = np.std(data[fea])
    data_mean = np.mean(data[fea])
    outliers_cut_off = data_std * 3
    lower_rule = data_mean - outliers_cut_off
    upper_rule = data_mean + outliers_cut_off
    data[fea+'_outliers'] = data[fea].apply(lambda x:str('异常值') if x > upper_rule or x < lower_rule else '正常值')
    return data
for fea in numerical_fea:
    data_train = find_outliers_by_3segama(data_train,fea)
for fea in numerical_fea:
    data_train = data_train[data_train[fea+'_outliers']=='正常值']
    data_train = data_train.reset_index(drop=True)

# %% [markdown]
# ### 处理异常值函数   分箱法

# %%
# 处理异常值函数   分箱法
def outliers_proc(data, col_name, scale=3):
    """
    用于清洗异常值，默认用 box_plot（scale=3）进行清洗
    :param data: 接收 pandas 数据格式
    :param col_name: pandas 列名
    :param scale: 尺度
    :return:
    """

    def box_plot_outliers(data_ser, box_scale):
        """
        利用箱线图去除异常值
        :param data_ser: 接收 pandas.Series 数据格式
        :param box_scale: 箱线图尺度，
        :return:
        """
        iqr = box_scale * (data_ser.quantile(0.75) - data_ser.quantile(0.25))
        val_low = data_ser.quantile(0.25) - iqr
        val_up = data_ser.quantile(0.75) + iqr
        rule_low = (data_ser < val_low)
        rule_up = (data_ser > val_up)
        return (rule_low, rule_up), (val_low, val_up)

    data_n = data.copy()
    data_series = data_n[col_name]
    rule, value = box_plot_outliers(data_series, box_scale=scale)
    index = np.arange(data_series.shape[0])[rule[0] | rule[1]]
    print("Delete number is: {}".format(len(index)))
    data_n = data_n.drop(index)
    data_n.reset_index(drop=True, inplace=True)
    print("Now column number is: {}".format(data_n.shape[0]))
    index_low = np.arange(data_series.shape[0])[rule[0]]
    outliers = data_series.iloc[index_low]
    print("Description of data less than the lower bound is:")
    print(pd.Series(outliers).describe())
    index_up = np.arange(data_series.shape[0])[rule[1]]
    outliers = data_series.iloc[index_up]
    print("Description of data larger than the upper bound is:")
    print(pd.Series(outliers).describe())
    
    fig, ax = plt.subplots(1, 2, figsize=(10, 7))
    sns.boxplot(y=data[col_name], data=data, palette="Set1", ax=ax[0])
    sns.boxplot(y=data_n[col_name], data=data_n, palette="Set1", ax=ax[1])
    return data_n

# %%
data1=outliers_proc(Data,'dti',scale=3)
# Out:
# Delete number is: 1011
# Now column number is: 798989
# Description of data less than the lower bound is:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: dti, dtype: float64
# Description of data larger than the upper bound is:
# count    1011.000000
# mean      133.762542
# std       166.192353
# min        60.880000
# 25%        68.185000
# 50%        79.820000
# 75%       114.300000
# max       999.000000
# Name: dti, dtype: float64

# %%
data1
# Out:
#             id  loanAmnt  term  interestRate  installment grade subGrade  \
# 0            0   35000.0     5         19.52       917.97     E       E2
# 1            1   18000.0     5         18.49       461.90     D       D2
# 2            2   12000.0     5         16.99       298.17     D       D3
# 3            3   11000.0     3          7.26       340.96     A       A4
# 4            4    3000.0     3         12.99       101.07     C       C2
# ...        ...       ...   ...           ...          ...   ...      ...
# 798984  799995   25000.0     3         14.49       860.41     C       C4
# 798985  799996   17000.0     3          7.90       531.94     A       A4
# 798986  799997    6000.0     3         13.33       203.12     C       C3
# 798987  799998   19200.0     3          6.92       592.14     A       A4
# 798988  799999    9000.0     3         11.06       294.91     B       B3
#
#         employmentTitle employmentLength  homeOwnership  ...    n5    n6  \
# ...

# %%
Train_data
# Out:
#               0         1         2         3         4         5         6   \
# 0       2.361518  1.772857  1.318073  1.835926  1.599082 -0.672559  2.050742
# 1       0.411102  1.772857  1.101948  0.091610  0.823469  1.387042 -0.908940
# 2      -0.277280  1.772857  0.787203 -0.534603  0.978592 -0.378166 -0.908940
# 3      -0.392011 -0.564061 -1.254445 -0.370945 -1.193124 -0.235970  0.570901
# 4      -1.309854 -0.564061 -0.052118 -1.288445  0.047856 -0.675055  0.570901
# ...          ...       ...       ...       ...       ...       ...       ...
# 799992  1.214214 -0.564061  0.262627  1.615778  0.358101 -0.650615  0.570901
# 799993  0.296371 -0.564061 -1.120153  0.359490 -1.193124 -0.401556 -0.908940
# 799994 -0.965662 -0.564061  0.019224 -0.898137  0.202979 -0.651337  0.570901
# 799995  0.548778 -0.564061 -1.325787  0.589735 -1.193124 -0.674145 -0.908940
# 799996 -0.621471 -0.564061 -0.457090 -0.547071 -0.572634 -0.675440 -0.908940
#
# ...

# %%
test_data
# Out:
#         loanAmnt  term  interestRate  installment  subGrade  employmentTitle  \
# 0        12000.0     5         26.30       361.42        24         141873.0
# 1         7000.0     3          6.92       215.89         3             38.0
# 2         8000.0     3          6.49       245.16         1          97905.0
# 3        35000.0     5         19.99       927.10        19           1746.0
# 4         1000.0     3         15.31        34.82        14            196.0
# ...          ...   ...           ...          ...       ...              ...
# 199995   25000.0     3         14.83       864.56        17         234972.0
# 199996   11200.0     3         11.99       371.95         9         102496.0
# 199997   14000.0     3          5.32       421.61         0            288.0
# 199998    7725.0     3         17.99       279.24        16             54.0
# 199999   25600.0     3          6.24       781.59         1          74893.0
#
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 799997 entries, 0 to 799996
# Data columns (total 43 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   loanAmnt            799997 non-null  float64
#  1   term                799997 non-null  int64
#  2   interestRate        799997 non-null  float64
#  3   installment         799997 non-null  float64
#  4   subGrade            799997 non-null  int64
#  5   employmentTitle     799997 non-null  float64
#  6   homeOwnership       799997 non-null  int64
#  7   annualIncome        799997 non-null  float64
#  8   verificationStatus  799997 non-null  int64
#  9   issueDate           799997 non-null  int64
#  10  purpose             799997 non-null  int64
#  11  postCode            799997 non-null  float64
#  12  regionCode          799997 non-null  int64
#  13  dti                 799997 non-null  float64
#  14  delinquency_2years  799997 non-null  float64
# ...

# %%
Test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 43 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       200000 non-null  float64
#  1   1       200000 non-null  float64
#  2   2       200000 non-null  float64
#  3   3       200000 non-null  float64
#  4   4       200000 non-null  float64
#  5   5       200000 non-null  float64
#  6   6       200000 non-null  float64
#  7   7       200000 non-null  float64
#  8   8       200000 non-null  float64
#  9   9       200000 non-null  float64
#  10  10      200000 non-null  float64
#  11  11      200000 non-null  float64
#  12  12      200000 non-null  float64
#  13  13      200000 non-null  float64
#  14  14      200000 non-null  float64
#  15  15      200000 non-null  float64
#  16  16      200000 non-null  float64
#  17  17      200000 non-null  float64
#  18  18      200000 non-null  float64
#  19  19      200000 non-null  float64
# ...

# %%
Train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799997 entries, 0 to 799996
# Data columns (total 43 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       799997 non-null  float64
#  1   1       799997 non-null  float64
#  2   2       799997 non-null  float64
#  3   3       799997 non-null  float64
#  4   4       799997 non-null  float64
#  5   5       799997 non-null  float64
#  6   6       799997 non-null  float64
#  7   7       799997 non-null  float64
#  8   8       799997 non-null  float64
#  9   9       799997 non-null  float64
#  10  10      799997 non-null  float64
#  11  11      799997 non-null  float64
#  12  12      799997 non-null  float64
#  13  13      799997 non-null  float64
#  14  14      799997 non-null  float64
#  15  15      799997 non-null  float64
#  16  16      799997 non-null  float64
#  17  17      799997 non-null  float64
#  18  18      799997 non-null  float64
#  19  19      799997 non-null  float64
# ...

# %%
for i in Train_data.columns:
    Train_data1=outliers_proc(Train_data,i,scale=3)
# Out:
# Delete number is: 0
# Now column number is: 799997
# Description of data less than the lower bound is:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: 0, dtype: float64
# Description of data larger than the upper bound is:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: 0, dtype: float64
# Delete number is: 193095
# Now column number is: 606902
# Description of data less than the lower bound is:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: 1, dtype: float64
# Description of data larger than the upper bound is:
# count    1.930950e+05
# mean     1.772857e+00
# std      6.801244e-13
# min      1.772857e+00
# 25%      1.772857e+00
# 50%      1.772857e+00
# 75%      1.772857e+00
# max      1.772857e+00
# Name: 1, dtype: float64
# ...

# %%
Train_data1.shape
# Out:
# (799997, 42)

# %%
# del Train_data[27]

# %%
# del Test_data[27]

# %%
Train_data
# Out:
#               0         1         2         3         4         5         6   \
# 0       2.361518  1.772857  1.318073  1.835926  1.599082 -0.672559  2.050742
# 1       0.411102  1.772857  1.101948  0.091610  0.823469  1.387042 -0.908940
# 2      -0.277280  1.772857  0.787203 -0.534603  0.978592 -0.378166 -0.908940
# 3      -0.392011 -0.564061 -1.254445 -0.370945 -1.193124 -0.235970  0.570901
# 4      -1.309854 -0.564061 -0.052118 -1.288445  0.047856 -0.675055  0.570901
# ...          ...       ...       ...       ...       ...       ...       ...
# 799992  1.214214 -0.564061  0.262627  1.615778  0.358101 -0.650615  0.570901
# 799993  0.296371 -0.564061 -1.120153  0.359490 -1.193124 -0.401556 -0.908940
# 799994 -0.965662 -0.564061  0.019224 -0.898137  0.202979 -0.651337  0.570901
# 799995  0.548778 -0.564061 -1.325787  0.589735 -1.193124 -0.674145 -0.908940
# 799996 -0.621471 -0.564061 -0.457090 -0.547071 -0.572634 -0.675440 -0.908940
#
# ...

# %%
Columns=train_data.columns
Columns1=list(Columns)
Columns1.remove('isDefault')
Columns1
# Out:
# ['loanAmnt',
#  'term',
#  'interestRate',
#  'installment',
#  'subGrade',
#  'employmentTitle',
#  'homeOwnership',
#  'annualIncome',
#  'verificationStatus',
#  'issueDate',
#  'purpose',
#  'postCode',
#  'regionCode',
#  'dti',
#  'delinquency_2years',
#  'ficoRangeLow',
#  'ficoRangeHigh',
#  'openAcc',
#  'pubRec',
#  'pubRecBankruptcies',
#  'revolBal',
#  'revolUtil',
#  'totalAcc',
#  'initialListStatus',
#  'applicationType',
#  'earliesCreditLine',
#  'title',
#  'n0',
#  'n1',
#  'n2',
#  'n3',
#  'n4',
#  'n5',
#  'n6',
#  'n7',
#  'n8',
#  'n9',
#  'n10',
#  'n11',
#  'n12',
#  'n13',
#  'n14']

# %%
# X.info()
# X['policyCode'].value_counts()
# del X['policyCode']
# del test_data['policyCode']
Train_data1=train_data
for i in Columns1:
    Train_data1=outliers_proc(Train_data1,i,scale=3)
# Out:
# Delete number is: 0
# Now column number is: 799997
# Description of data less than the lower bound is:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: loanAmnt, dtype: float64
# Description of data larger than the upper bound is:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: loanAmnt, dtype: float64
# Delete number is: 193095
# Now column number is: 606902
# Description of data less than the lower bound is:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: term, dtype: float64
# Description of data larger than the upper bound is:
# count    193095.0
# mean          5.0
# std           0.0
# min           5.0
# 25%           5.0
# 50%           5.0
# 75%           5.0
# max           5.0
# Name: term, dtype: float64
# Delete number is: 0
# ...

# %%
Train_data1.shape
# Out:
# (313441, 43)

# %%
X
# Out:
#         loanAmnt  term  interestRate  installment  subGrade  employmentTitle  \
# 0        35000.0     5         19.52       917.97        21            320.0
# 1        18000.0     5         18.49       461.90        16         219843.0
# 2        12000.0     5         16.99       298.17        17          31698.0
# 3        11000.0     3          7.26       340.96         3          46854.0
# 4         3000.0     3         12.99       101.07        11             54.0
# ...          ...   ...           ...          ...       ...              ...
# 799992   25000.0     3         14.49       860.41        13           2659.0
# 799993   17000.0     3          7.90       531.94         3          29205.0
# 799994    6000.0     3         13.33       203.12        12           2582.0
# 799995   19200.0     3          6.92       592.14         3            151.0
# 799996    9000.0     3         11.06       294.91         7             13.0
#
# ...

# %% [markdown]
# #    建模

# %%
X    
test_data
# Out:
#         loanAmnt  term  interestRate  installment  subGrade  employmentTitle  \
# 0        12000.0     5         26.30       361.42        24         141873.0
# 1         7000.0     3          6.92       215.89         3             38.0
# 2         8000.0     3          6.49       245.16         1          97905.0
# 3        35000.0     5         19.99       927.10        19           1746.0
# 4         1000.0     3         15.31        34.82        14            196.0
# ...          ...   ...           ...          ...       ...              ...
# 199995   25000.0     3         14.83       864.56        17         234972.0
# 199996   11200.0     3         11.99       371.95         9         102496.0
# 199997   14000.0     3          5.32       421.61         0            288.0
# 199998    7725.0     3         17.99       279.24        16             54.0
# 199999   25600.0     3          6.24       781.59         1          74893.0
#
# ...

# %%
Train_data
Test_data
# Out:
#               0         1         2         3         4         5         6   \
# 0      -0.276775  1.772735  2.736946 -0.292149  2.060671  0.651121  2.056912
# 1      -0.850872 -0.564100 -1.322113 -0.849783 -1.189241 -0.677270  0.573582
# 2      -0.736052 -0.564100 -1.412175 -0.737628 -1.498756  0.239328  2.056912
# 3       2.364068  1.772735  1.415344  1.875393  1.286882 -0.661273 -0.909749
# 4      -1.539787 -0.564100  0.435137 -1.543597  0.513094 -0.675790  0.573582
# ...          ...       ...       ...       ...       ...       ...       ...
# 199995  1.215875 -0.564100  0.334603  1.635755  0.977367  1.523062 -0.909749
# 199996 -0.368631 -0.564100 -0.260223 -0.251801 -0.260695  0.282326 -0.909749
# 199997 -0.047137 -0.564100 -1.657226 -0.061516 -1.653514 -0.674928 -0.909749
# 199998 -0.767628 -0.564100  0.996452 -0.607042  0.822609 -0.677120 -0.909749
# 199999  1.284767 -0.564100 -1.464536  1.317835 -1.498756  0.023803 -0.909749
#
# ...

# %%
Train_data1.shape
Test_data
# Out:
#               0         1         2         3         4         5         6   \
# 0      -0.276775  1.772735  2.736946 -0.292149  2.060671  0.651121  2.056912
# 1      -0.850872 -0.564100 -1.322113 -0.849783 -1.189241 -0.677270  0.573582
# 2      -0.736052 -0.564100 -1.412175 -0.737628 -1.498756  0.239328  2.056912
# 3       2.364068  1.772735  1.415344  1.875393  1.286882 -0.661273 -0.909749
# 4      -1.539787 -0.564100  0.435137 -1.543597  0.513094 -0.675790  0.573582
# ...          ...       ...       ...       ...       ...       ...       ...
# 199995  1.215875 -0.564100  0.334603  1.635755  0.977367  1.523062 -0.909749
# 199996 -0.368631 -0.564100 -0.260223 -0.251801 -0.260695  0.282326 -0.909749
# 199997 -0.047137 -0.564100 -1.657226 -0.061516 -1.653514 -0.674928 -0.909749
# 199998 -0.767628 -0.564100  0.996452 -0.607042  0.822609 -0.677120 -0.909749
# 199999  1.284767 -0.564100 -1.464536  1.317835 -1.498756  0.023803 -0.909749
#
# ...

# %% [markdown]
# ###   数据    X

# %%
from sklearn.linear_model import LogisticRegression as LR
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=0.3)

LR_=LR(C=0.01)
LR_.fit(Xtrain,Ytrain)
score=LR_.score(Xtest,Ytest)

score
# Out:
# E:\Phthon\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# E:\Phthon\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7999083333333333

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
RFC_=RFC(n_estimators=100,random_state=420)
RFC_.fit(Xtrain,Ytrain)
# Out:
# <ipython-input-314-580b9adcfe30>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC_.fit(Xtrain,Ytrain)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-314-580b9adcfe30> in <module>
#       2 RFC_=RFC(n_estimators=100,random_state=420)
#       3 RFC_.fit(Xtrain,Ytrain)
# ----> 4 RFC.score(Xtest,Ytest)
#
# TypeError: score() missing 1 required positional argument: 'y'

# %%
RFC_.score(Xtest,Ytest)
# Out:
# 0.8023541666666667

# %%
from xgboost import XGBClassifier as XGBC
xgbc=XGBC(n_estimators=101,random_state=42)
xgbc.fit(Xtrain,Ytrain)
xgbc.score(Xtest,Ytest)
# Out:
# [10:14:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# E:\Phthon\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# 0.8048208333333333

# %%
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
from xgboost import XGBClassifier as XGBC
a=[]
from xgboost import XGBClassifier as XGBC
for i in range(100,150,10):
    xgbc=XGBC(n_estimators=i)
    score=cross_val_score(xgbc,X,Y,cv=10).mean()
    a.append(score)
plt.figure(figsize=(20,5))
plt.plot(np.arange(100,150,10),a)
plt.show()
# Out:
# E:\Phthon\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# E:\Phthon\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %% [markdown]
# # 数据 Train_data

# %%
from sklearn.linear_model import LogisticRegression as LR
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest=train_test_split(Train_data,Y,test_size=0.3)

LR_=LR(C=0.8)
LR_.fit(Xtrain,Ytrain)
score=LR_.score(Xtest,Ytest)

score
# Out:
# E:\Phthon\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 0.8031625

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
RFC_=RFC(n_estimators=110,random_state=420)
RFC_.fit(Xtrain,Ytrain)
RFC_.score(Xtest,Ytest)
# Out:
# <ipython-input-393-0ebeedbb22e8>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC_.fit(Xtrain,Ytrain)
# 0.8025875

# %%
from xgboost import XGBClassifier as XGBC
xgbc=XGBC(n_estimators=101,random_state=42)
xgbc.fit(Xtrain,Ytrain)
xgbc.score(Xtest,Ytest)
# Out:
# E:\Phthon\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# E:\Phthon\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %% [markdown]
# # 数据 Train_data1

# %%
Train_data1
Y1=pd.DataFrame(Train_data1["isDefault"])
X1=Train_data1.loc[:,Train_data1.columns!="isDefault"]

# %%
Y1["isDefault"].value_counts()
# Out:
# 0    263949
# 1     49492
# Name: isDefault, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression as LR
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X1,Y1,test_size=0.3)

LR_=LR(C=0.01)
LR_.fit(Xtrain,Ytrain)
score=LR_.score(Xtest,Ytest)
score
# Out:
# E:\Phthon\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# E:\Phthon\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8418108536364893

# %%
LR_=LR(penalty='l2',
dual=False,
tol=0.0001,
C=0.8,
fit_intercept=True,
intercept_scaling=1,
class_weight=None,
random_state=None,
solver='lbfgs',
max_iter=100,
multi_class='auto',
verbose=0,
warm_start=False,
n_jobs=None,
l1_ratio=None)
LR_.fit(Xtrain,Ytrain)
score=LR_.score(Xtest,Ytest)
score
# Out:
# E:\Phthon\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# E:\Phthon\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.841672604298491

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
RFC_=RFC(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=None, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=1, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, n_estimators=120,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
RFC_.fit(Xtrain,Ytrain)
RFC_.score(Xtest,Ytest)
# Out:
# <ipython-input-399-54b66e372fe0>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC_.fit(Xtrain,Ytrain)
# 0.8426509842289409

# %%
from xgboost import XGBClassifier as XGBC
xgbc=XGBC(n_estimators=101,random_state=42)
xgbc.fit(Xtrain,Ytrain)
xgbc.score(Xtest,Ytest)
# Out:
# E:\Phthon\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# E:\Phthon\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
from sklearn.metrics import roc_auc_score as auc
aa=pd.DataFrame(xgbc.predict_proba(Xtest))
bb=pd.DataFrame(aa[1])
cc=pd.DataFrame(Ytest)
auc(cc,bb)
# Out:
# E:\Phthon\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# 0.767315495806214

# %% [markdown]
# ### 对训练集进行预测

# %%
from xgboost import XGBClassifier as XGBC
from sklearn.metrics import roc_auc_score as auc
xgbc=XGBC(n_estimators=101,eta=0.22,subsample=0.95)
xgbc.fit(X1,Y1)
aa=pd.DataFrame(xgbc.predict_proba(Test_data))
bb=pd.DataFrame(aa[1])
# Out:
# E:\Phthon\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# E:\Phthon\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
# 预测结果
Predict=pd.DataFrame(xgbc.predict(Test_data))
Predict[0].value_counts()
Predict
# Out:
# E:\Phthon\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
#         0
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# ...    ..
# 199995  0
# 199996  0
# 199997  0
# 199998  0
# 199999  0
#
# [200000 rows x 1 columns]

# %%
# 预测概率
ff=pd.DataFrame()
ff["id"]=np.arange(800000,1000000,1)
ff["isDefault"]=bb
ff["isDefault_predict"]=Predict[0]
ff
# Out:
#             id  isDefault  isDefault_predict
# 0       800000   0.208898                  0
# 1       800001   0.192078                  0
# 2       800002   0.282253                  0
# 3       800003   0.223128                  0
# 4       800004   0.261479                  0
# ...        ...        ...                ...
# 199995  999995   0.393279                  0
# 199996  999996   0.220048                  0
# 199997  999997   0.401605                  0
# 199998  999998   0.140370                  0
# 199999  999999   0.437795                  0
#
# [200000 rows x 3 columns]

# %% [markdown]
# #   模型融合

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import BayesianRidge
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor,AdaBoostRegressor,ExtraTreesRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.datasets import load_boston
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.model_selection import KFold
from xgboost import XGBClassifier as XGBC


from sklearn.model_selection import KFold
kf=KFold(n_splits=5)
models=[XGBC(n_estimators=101,random_state=42),RandomForestClassifier(n_estimators=100,random_state=420),LogisticRegression(C=0.2),ExtraTreesClassifier(n_estimators=100),XGBC(n_estimators=101),GradientBoostingClassifier(n_estimators=100),AdaBoostClassifier(n_estimators=100),ExtraTreesClassifier(n_estimators=100),XGBC(n_estimators=101)]

# %%
n_train=Xtrain.shape[0]
n_test=Xtest.shape[0]

# %%
def get_oof(model,Xtrain,Ytrain,X_test):
    oof_train=np.zeros((n_train,))    # 构造一个 1*354 的一维0特征矩阵
    oof_test=np.zeros((n_test,))      #  构造一个  1* 152 的一维0 矩阵
    oof_test_skf=np.zeros((5,n_test)) #5* 152
    for i,(train_index,test_index) in enumerate(kf.split(Xtrain)):
        kf_x_train=Xtrain[train_index]
        kf_y_train=Ytrain[train_index]
        kf_x_test=Xtrain[test_index]
        model=model.fit(kf_x_train,kf_y_train)
        oof_train[test_index]=model.predict(kf_x_test)
        oof_test_skf[i,:]=model.predict(Xtest)
    oof_test[:]=oof_test_skf.mean(axis=0)
    return oof_train,oof_test
number_models=len(models)
Xtrain_new=np.zeros((n_train,number_models))
Ytrain_new=np.zeros((n_test,number_models))
for i,classifier in enumerate(models):
    Xtrain_new[:,i],Ytrain_new[:,i]=get_oof(classifier,Xtrain,Ytrain,Xtest)



LR=LogisticRegression()
LR.fit(Xtrain_new,Ytrain)
score=LR.score(Ytrain_new,Ytest)
score
